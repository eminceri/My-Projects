# %% [markdown]
# # Example Functions

# %% [raw]
# df.groupby('age').km.describe()

# %% [raw]
# df.groupby(['make_model', 'age']).km.describe()

# %% [raw]
# df.groupby(['make_model', 'age', 'body_type']).price.describe()

# %% [raw]
# df["body_type"].fillna(df["body_type"].mode()[0])

# %% [raw]
# df.loc[df["make_model"] == "Audi A1", "body_type"].fillna(df[df["make_model"]=="Audi A1"]["body_type"].mode()[0])

# %% [raw]
# for group in list((df["make_model"]).unique()):
#     cond = df["make_model"]==group
#     mode = list(df[cond]["body_type"].mode())
#     if mode != []:
#          df.loc[cond, "body_type"] = df.loc[cond, "body_type"].fillna(df[cond]["body_type"].mode()[0])
#     else:
#         df.loc[cond, "body_type"] = df.loc[cond, "body_type"].fillna(df["body_type"].mode()[0])

# %% [raw]
# df["previous_owners_2"].fillna(method="ffill")

# %% [raw]
# df.loc[df["age"]==0, "previous_owners_2"].fillna(method="ffill")

# %% [raw]
# for group in list(df["age"].unique()):
#     cond = df["age"] == group
#     df.loc[cond, "previous_owners_2"] = df.loc[cond, "previous_owners_2"]].fillna(method="ffill").fillna(method="bfill")
# df["previous_owners_2"] = df["previous_owners_2"].fillna(method="ffill").fillna(method="bfill")

# %% [raw]
# df.["paint_type"].fillna(method="ffill")

# %% [raw]
# df.loc[df["age"]==0, "paint_type"].fillna(method="ffill")

# %% [raw]
# for group in list(df["make_model"].unique()):
#     cond = df["make_model"]==group
#     df.loc[cond, "paint_type"] = df.loc[cond, "paint_type"].fillna(method="ffill").fillna(method="bfill")
# df["paint_type"] = df["paint_type"].fillna(method="ffill").fillna(method="bfill")

# %% [raw]
# for group1 in list(df['make_model'].unique()):
#     for group2 in list(df['body_type'].unique()):
#         cond2 = (df['make_model']==group1 & df['body_type']==group2)
#         df.loc[cond2, 'paint_type'] = df.loc[cond2, 'paint_type'].fillna(method='ffill').fillna(method='bfill')
#
# for group1 in list(df["make_model"].unique()):
#     cond1 = df["make_model"]==group1
#     df.loc[cond1, "paint_type"] = df.loc[cond1, "paint_type"].fillna(method="ffill").fillna(method="bfill")
#
# df["paint_type"] = df["paint_type"].fillna(method="ffill").fillna(method="bfill")

# %%
## Ignore Warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)# çizeceğimiz şemaların ölçülerini belirlemiş olduk
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df = pd.read_csv('autoscout_clean.csv')

# %%
df.shape
# Out:
# (15919, 33)

# %%
df.describe().T
# Out:
#                         count      mean       std    min       25%       50%  \
# price               15919.000 18019.897  7386.169 13.000 12850.000 16900.000
# km                  14895.000 34130.128 37352.978  0.000  5153.000 22740.000
# nr._of_doors        15707.000     4.656     0.645  1.000     4.000     5.000
# nr._of_seats        14942.000     4.950     0.490  2.000     5.000     5.000
# displacement        15423.000  1423.541   333.531  1.000  1229.000  1461.000
# cylinders           10239.000     3.797     0.415  1.000     4.000     4.000
# co2_emission        13483.000   123.740   269.952  0.000   104.000   116.000
# gears               11207.000     5.925     0.848  1.000     5.000     6.000
# age                 14322.000     1.542     1.077  0.000     1.000     1.000
# previous_owners_2    9279.000     1.068     0.330  0.000     1.000     1.000
# hp_kw               15831.000    88.368    26.835  1.000    66.000    85.000
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# make_model             0.000
# body_type              0.377
# price                  0.000
# vat                   28.350
# km                     6.433
# body_color             3.750
# paint_type            36.259
# nr._of_doors           1.332
# nr._of_seats           6.137
# gearing_type           0.000
# displacement           3.116
# cylinders             35.681
# drive_chain           43.081
# co2_emission          15.302
# emission_class        22.790
# comfort&convenience    5.779
# entertainment&media    8.631
# extras                18.607
# safety&security        6.169
# gears                 29.600
# age                   10.032
# previous_owners_2     41.711
# hp_kw                  0.553
# type_1                 0.013
# fuel_type              0.013
# particulate_filter     0.000
# warranty_2            69.514
# upholstery_type       30.599
# upholstery_color      31.899
# weight_kg             43.809
# consumption_comb      12.771
# consumption_city      15.302
# ...

# %%
df.isnull().sum()>0
# Out:
# make_model             False
# body_type               True
# price                  False
# vat                     True
# km                      True
# body_color              True
# paint_type              True
# nr._of_doors            True
# nr._of_seats            True
# gearing_type           False
# displacement            True
# cylinders               True
# drive_chain             True
# co2_emission            True
# emission_class          True
# comfort&convenience     True
# entertainment&media     True
# extras                  True
# safety&security         True
# gears                   True
# age                     True
# previous_owners_2       True
# hp_kw                   True
# type_1                  True
# fuel_type               True
# particulate_filter     False
# warranty_2              True
# upholstery_type         True
# upholstery_color        True
# weight_kg               True
# consumption_comb        True
# consumption_city        True
# ...

# %%
df.head().T
# Out:
#                                                                      0  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                           56013.000
# body_color                                                       Black
# paint_type                                                    Metallic
# nr._of_doors                                                     5.000
# nr._of_seats                                                     5.000
# gearing_type                                                 Automatic
# displacement                                                  1422.000
# cylinders                                                        3.000
# ...

# %%
def first_looking(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()/df.shape[0]*100, 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print(df[col].value_counts(dropna = False))

# %% [markdown]
# # body_type

# %%
first_looking("body_type")
# Out:
# column name    :  body_type
# --------------------------------
# per_of_nulls   :  % 0.38
# num_of_nulls   :  60
# num_of_uniques :  9
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.groupby(['make_model']).body_type.describe()
# Out:
#                count unique            top  freq
# make_model
# Audi A1         2614      6         Sedans  1538
# Audi A2            1      1       Off-Road     1
# Audi A3         3090      6         Sedans  2598
# Opel Astra      2519      6  Station wagon  1211
# Opel Corsa      2217      7        Compact  1230
# Opel Insignia   2595      7  Station wagon  1611
# Renault Clio    1824      8         Sedans   918
# Renault Duster    34      1       Off-Road    34
# Renault Espace   965      8            Van   777

# %%
for group in list((df["make_model"]).unique()):
    cond = df["make_model"]==group
    mode = list(df[cond]["body_type"].mode())
    if mode != []:
         df.loc[cond, "body_type"] = df.loc[cond, "body_type"].fillna(df[cond]["body_type"].mode()[0])
    else:
        df.loc[cond, "body_type"] = df.loc[cond, "body_type"].fillna(df["body_type"].mode()[0])

# %%
first_looking("body_type")
# Out:
# column name    :  body_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  9
# Sedans           7925
# Station wagon    3563
# Compact          3155
# Van               809
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %% [markdown]
# # vat

# %%
first_looking('vat')
# Out:
# column name    :  vat
# --------------------------------
# per_of_nulls   :  % 28.35
# num_of_nulls   :  4513
# num_of_uniques :  2
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %%
# vat ile diger sutunlarla iliski bulamadigimiz icin ffill ile doldurduk.
df["vat"].fillna(method="ffill", inplace=True)

# %%
df.vat.value_counts(dropna=False)
# Out:
# VAT deductible      15048
# Price negotiable      871
# Name: vat, dtype: int64

# %% [markdown]
# # body_color

# %%
first_looking('body_color')
# Out:
# column name    :  body_color
# --------------------------------
# per_of_nulls   :  % 3.75
# num_of_nulls   :  597
# num_of_uniques :  14
# Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'body_color'] = df.loc[cond2, 'body_color'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "body_color"] = df.loc[cond1, "body_color"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('body_color')
# Out:
# column name    :  body_color
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  14
# Black     3901
# Grey      3620
# White     3514
# Silver    1710
# Blue      1515
# Red        995
# Brown      298
# Green      166
# Beige      120
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64

# %%
df.groupby(['body_color']).price.describe()
# Out:
#               count      mean       std       min       25%       50%  \
# body_color
# Beige       120.000 17130.350  6658.931  6499.000 10989.750 17095.000
# Black      3901.000 19026.205  7534.330  6200.000 14000.000 17500.000
# Blue       1515.000 17397.532  6929.671  5990.000 12545.000 16200.000
# Bronze        6.000 17458.167  5911.971  5950.000 17550.000 19700.000
# Brown       298.000 18882.238  6582.517  7000.000 14990.000 17480.000
# Gold          2.000   134.000   171.120    13.000    73.500   134.000
# Green       166.000 18434.120  6078.080  6290.000 13992.500 17985.000
# Grey       3620.000 18958.121  7789.788   120.000 13477.500 18000.000
# Orange        3.000 18166.667 17347.438  5555.000  8275.000 10995.000
# Red         995.000 15853.453  5558.013  4990.000 11400.000 15480.000
# Silver     1710.000 16606.356  5862.332  4950.000 11950.000 15950.000
# Violet       18.000 23005.389  5444.337 13700.000 19925.000 24200.000
# ...

# %% [markdown]
# # paint_type

# %%
first_looking('paint_type')
# Out:
# column name    :  paint_type
# --------------------------------
# per_of_nulls   :  % 36.26
# num_of_nulls   :  5772
# num_of_uniques :  3
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'paint_type'] = df.loc[cond2, 'paint_type'].fillna(method='ffill').fillna(method='bfill')

# %%
first_looking('paint_type')
# Out:
# column name    :  paint_type
# --------------------------------
# per_of_nulls   :  % 0.07
# num_of_nulls   :  11
# num_of_uniques :  3
# Metallic       15244
# Uni/basic        632
# Perl effect       32
# NaN               11
# Name: paint_type, dtype: int64

# %%
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "paint_type"] = df.loc[cond1, "paint_type"].fillna(method="ffill").fillna(method="bfill")

#df["paint_type"] = df["paint_type"].fillna(method="ffill").fillna(method="bfill") ?kodda bu neden var?

# %%
first_looking('paint_type')
# Out:
# column name    :  paint_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  3
# Metallic       15255
# Uni/basic        632
# Perl effect       32
# Name: paint_type, dtype: int64

# %% [markdown]
# # nr._of_doors

# %%
first_looking('nr._of_doors')
# Out:
# column name    :  nr._of_doors
# --------------------------------
# per_of_nulls   :  % 1.33
# num_of_nulls   :  212
# num_of_uniques :  6
# 5.000    11575
# 4.000     3079
# 3.000      832
# 2.000      219
# NaN        212
# 1.000        1
# 7.000        1
# Name: nr._of_doors, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'nr._of_doors'] = df.loc[cond2, 'nr._of_doors'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "nr._of_doors"] = df.loc[cond1, "nr._of_doors"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('nr._of_doors')
# Out:
# column name    :  nr._of_doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# 5.000    11729
# 4.000     3112
# 3.000      853
# 2.000      222
# 1.000        2
# 7.000        1
# Name: nr._of_doors, dtype: int64

# %% [markdown]
# # nr._of_seats

# %%
first_looking('nr._of_seats')
# Out:
# column name    :  nr._of_seats
# --------------------------------
# per_of_nulls   :  % 6.14
# num_of_nulls   :  977
# num_of_uniques :  6
# 5.000    13336
# 4.000     1125
# NaN        977
# 7.000      362
# 2.000      116
# 6.000        2
# 3.000        1
# Name: nr._of_seats, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'nr._of_seats'] = df.loc[cond2, 'nr._of_seats'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "nr._of_seats"] = df.loc[cond1, "nr._of_seats"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('nr._of_seats')
# Out:
# column name    :  nr._of_seats
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# 5.000    14182
# 4.000     1194
# 7.000      409
# 2.000      131
# 6.000        2
# 3.000        1
# Name: nr._of_seats, dtype: int64

# %% [markdown]
# # displacement (cc)

# %%
first_looking('displacement')
# Out:
# column name    :  displacement
# --------------------------------
# per_of_nulls   :  % 3.12
# num_of_nulls   :  496
# num_of_uniques :  77
# 1598.000     4761
# 999.000      2438
# 1398.000     1314
# 1399.000      749
# 1229.000      677
# 1956.000      670
# 1461.000      595
# 1490.000      559
# NaN           496
# 1422.000      467
# 1197.000      353
# 898.000       351
# 1395.000      320
# 1968.000      301
# 1149.000      288
# 1618.000      212
# 1798.000      210
# 1498.000      196
# 1600.000      130
# 1248.000      110
# 1997.000      103
# 1364.000      102
# 1400.000       90
# 998.000        72
# 1500.000       50
# 2000.000       46
# 1000.000       40
# 1.000          36
# 1998.000       25
# 2480.000       20
# 1200.000       18
# 1984.000       18
# 1397.000       11
# 899.000        11
# 160.000         6
# 929.000         5
# 1499.000        5
# 997.000         4
# 1596.000        4
# 139.000         4
# 900.000         4
# 1599.000        3
# ...

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'displacement'] = df.loc[cond2, 'displacement'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "displacement"] = df.loc[cond1, "displacement"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('displacement')
# Out:
# column name    :  displacement
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  77
# 1598.000     4924
# 999.000      2483
# 1398.000     1349
# 1399.000      769
# 1229.000      712
# 1956.000      690
# 1461.000      635
# 1490.000      580
# 1422.000      469
# 1197.000      371
# 898.000       371
# 1395.000      324
# 1968.000      310
# 1149.000      297
# 1798.000      228
# 1618.000      219
# 1498.000      196
# 1600.000      133
# 1248.000      114
# 1997.000      109
# 1364.000      106
# 1400.000       95
# 998.000        72
# 1500.000       53
# 2000.000       47
# 1000.000       41
# 1.000          36
# 1998.000       27
# 2480.000       20
# 1200.000       18
# 1984.000       18
# 1397.000       11
# 899.000        11
# 160.000         6
# 997.000         5
# 929.000         5
# 1499.000        5
# 1596.000        4
# 139.000         4
# 900.000         4
# 1599.000        3
# 1199.000        3
# 1396.000        3
# ...

# %% [markdown]
# # cylinders

# %%
first_looking('cylinders')
# Out:
# column name    :  cylinders
# --------------------------------
# per_of_nulls   :  % 35.68
# num_of_nulls   :  5680
# num_of_uniques :  7
# 4.000    8105
# NaN      5680
# 3.000    2104
# 5.000      22
# 6.000       3
# 8.000       2
# 2.000       2
# 1.000       1
# Name: cylinders, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'cylinders'] = df.loc[cond2, 'cylinders'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "cylinders"] = df.loc[cond1, "cylinders"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('cylinders')
# Out:
# column name    :  cylinders
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  1
# num_of_uniques :  7
# 4.000    12508
# 3.000     3375
# 5.000       23
# 8.000        4
# 6.000        3
# 2.000        3
# 1.000        2
# NaN          1
# Name: cylinders, dtype: int64

# %%
df[df.cylinders.isnull() == True]
# Out:
#      make_model body_type  price             vat        km body_color  \
# 2614    Audi A2  Off-Road  28200  VAT deductible 26166.000       Grey
#
#      paint_type  nr._of_doors  nr._of_seats gearing_type  displacement  \
# 2614   Metallic         5.000         5.000       Manual      1598.000
#
#       cylinders drive_chain  co2_emission emission_class  \
# 2614        NaN       front           NaN         Euro 6
#
#                                     comfort&convenience  \
# 2614  Air conditioning,Armrest,Automatic climate con...
#
#                                     entertainment&media        extras  \
# 2614  Bluetooth,CD player,Hands-free equipment,MP3,O...  Alloy wheels
#
#                                         safety&security  gears   age  \
# 2614  ABS,Adaptive Cruise Control,Central door lock,...    NaN 1.000
#
#       previous_owners_2  hp_kw          type_1 fuel_type  particulate_filter  \
# ...

# %%
df[(df.make_model=='Audi A2')]
# Out:
#      make_model body_type  price             vat        km body_color  \
# 2614    Audi A2  Off-Road  28200  VAT deductible 26166.000       Grey
#
#      paint_type  nr._of_doors  nr._of_seats gearing_type  displacement  \
# 2614   Metallic         5.000         5.000       Manual      1598.000
#
#       cylinders drive_chain  co2_emission emission_class  \
# 2614        NaN       front           NaN         Euro 6
#
#                                     comfort&convenience  \
# 2614  Air conditioning,Armrest,Automatic climate con...
#
#                                     entertainment&media        extras  \
# 2614  Bluetooth,CD player,Hands-free equipment,MP3,O...  Alloy wheels
#
#                                         safety&security  gears   age  \
# 2614  ABS,Adaptive Cruise Control,Central door lock,...    NaN 1.000
#
#       previous_owners_2  hp_kw          type_1 fuel_type  particulate_filter  \
# ...

# %%
df[(df['body_type']=="Off-Road")].T
# Out:
#                                                                  2614   \
# make_model                                                     Audi A2
# body_type                                                     Off-Road
# price                                                            28200
# vat                                                     VAT deductible
# km                                                           26166.000
# body_color                                                        Grey
# paint_type                                                    Metallic
# nr._of_doors                                                     5.000
# nr._of_seats                                                     5.000
# gearing_type                                                    Manual
# displacement                                                  1598.000
# cylinders                                                          NaN
# ...

# %%
# Off-Road ların hepsi 4 cylinders olduğu için Nan 4 ile doldurduk 

df["cylinders"][(df['body_type']=="Off-Road")].unique()
# Out:
# array([nan,  4.])

# %%
df.cylinders.fillna(value=4.000, inplace=True)

# %%
df.cylinders.value_counts(dropna= False)
# Out:
# 4.000    12509
# 3.000     3375
# 5.000       23
# 8.000        4
# 6.000        3
# 2.000        3
# 1.000        2
# Name: cylinders, dtype: int64

# %% [markdown]
# # drive_chain

# %%
first_looking('drive_chain')
# Out:
# column name    :  drive_chain
# --------------------------------
# per_of_nulls   :  % 43.08
# num_of_nulls   :  6858
# num_of_uniques :  3
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'drive_chain'] = df.loc[cond2, 'drive_chain'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "drive_chain"] = df.loc[cond1, "drive_chain"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('drive_chain')
# Out:
# column name    :  drive_chain
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  3
# front    15575
# 4WD        339
# rear         5
# Name: drive_chain, dtype: int64

# %% [markdown]
# # co2_emission

# %%
first_looking('co2_emission')
# Out:
# column name    :  co2_emission
# --------------------------------
# per_of_nulls   :  % 15.3
# num_of_nulls   :  2436
# num_of_uniques :  122
# NaN         2436
# 120.000      740
# 99.000       545
# 97.000       537
# 104.000      501
#             ...
# 14.000         1
# 1060.000       1
# 51.000         1
# 165.000        1
# 193.000        1
# Name: co2_emission, Length: 123, dtype: int64

# %%
#co2 emission sutunu fiyata bir etkisi olmadigi icin ve Co2 emisyonu yerine emission_class kullanmak daha mantkli oldugu icin co_2_emission sutununu dusurduk.
df.drop('co2_emission', axis=1, inplace=True)

# %% [markdown]
# # emission_class

# %%
first_looking("emission_class")
# Out:
# column name    :  emission_class
# --------------------------------
# per_of_nulls   :  % 22.79
# num_of_nulls   :  3628
# num_of_uniques :  3
# Euro 6    12173
# NaN        3628
# Euro 5       78
# Euro 4       40
# Name: emission_class, dtype: int64

# %%
for group1 in list(df['fuel_type'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['fuel_type']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'emission_class'] = df.loc[cond2, 'emission_class'].fillna(method='ffill').fillna(method='bfill')
    
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "emission_class"] = df.loc[cond1, "emission_class"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking("emission_class")
# Out:
# column name    :  emission_class
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  3
# Euro 6    15782
# Euro 5       94
# Euro 4       43
# Name: emission_class, dtype: int64

# %% [markdown]
# # comfort&convenience

# %%
first_looking("comfort&convenience")
# Out:
# column name    :  comfort&convenience
# --------------------------------
# per_of_nulls   :  % 5.78
# num_of_nulls   :  920
# num_of_uniques :  6198
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# ...

# %%
df['comfort&convenience'].str.split(',', expand=True).stack().value_counts()
# Out:
# Air conditioning                       14315
# Power windows                          13914
# Electrical side mirrors                11881
# Multi-function steering wheel          11083
# Cruise control                         10881
# Park Distance Control                  10190
# Parking assist system sensors rear      9694
# Leather steering wheel                  9386
# Start-stop system                       8881
# Automatic climate control               8747
# Rain sensor                             8615
# Navigation system                       8166
# Light sensor                            7672
# Armrest                                 7225
# Seat heating                            7078
# Hill Holder                             6745
# Parking assist system sensors front     5838
# Parking assist system camera            3421
# Lumbar support                          3226
# Heated steering wheel                   3017
# Keyless central door lock               2613
# ...

# %%
def fill(df, group_col1, group_col2, col_name, method): # method can be "mode" or "median" or "ffill"
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

# %%
fill(df, 'make_model', 'body_type', 'comfort&convenience', 'mode')

# %%
first_looking('comfort&convenience')
# Out:
# column name    :  comfort&convenience
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6198
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   315
# ...

# %% [markdown]
# # entertainment&media

# %%
first_looking('entertainment&media')
# Out:
# column name    :  entertainment&media
# --------------------------------
# per_of_nulls   :  % 8.63
# num_of_nulls   :  1374
# num_of_uniques :  346
# NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# ...

# %%
fill(df, 'make_model', 'body_type', 'entertainment&media', 'mode')

# %%
first_looking('entertainment&media')
# Out:
# column name    :  entertainment&media
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  346
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                      1639
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                  1063
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB        1007
# On-board computer                                                                681
# Radio                                                                            558
#                                                                                 ...
# Bluetooth,CD player,MP3                                                            1
# CD player,USB                                                                      1
# Bluetooth,CD player,Digital radio,Radio,USB                                        1
# ...

# %% [markdown]
# # extras

# %%
first_looking('extras')
# Out:
# column name    :  extras
# --------------------------------
# per_of_nulls   :  % 18.61
# num_of_nulls   :  2962
# num_of_uniques :  659
# Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# ...

# %%
fill(df, 'make_model', 'body_type', 'extras', 'mode')

# %%
first_looking('extras')
# Out:
# column name    :  extras
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  659
# Alloy wheels                                                                                               5884
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  582
# Alloy wheels,Touch screen,Voice Control                                                                     544
# Roof rack                                                                                                   538
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# ...

# %% [markdown]
# # safety&security

# %%
first_looking('safety&security')
# Out:
# column name    :  safety&security
# --------------------------------
# per_of_nulls   :  % 6.17
# num_of_nulls   :  982
# num_of_uniques :  4443
# NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ...

# %%
fill(df, 'make_model', 'body_type', 'safety&security', 'mode')

# %%
first_looking('safety&security')
# Out:
# column name    :  safety&security
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4443
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      729
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                 480
# ...

# %% [markdown]
# # gears

# %%
first_looking('gears')
# Out:
# column name    :  gears
# --------------------------------
# per_of_nulls   :  % 29.6
# num_of_nulls   :  4712
# num_of_uniques :  10
# 6.000     5822
# NaN       4712
# 5.000     3239
# 7.000     1908
# 8.000      224
# 9.000        6
# 1.000        2
# 3.000        2
# 4.000        2
# 2.000        1
# 50.000       1
# Name: gears, dtype: int64

# %%
df.gears[(df.gears == 1) | (df.gears == 2) | (df.gears == 3) | (df.gears == 4) | (df.gears == 9) | (df.gears == 50)] = np.nan

# %%
first_looking('gears')
# Out:
# column name    :  gears
# --------------------------------
# per_of_nulls   :  % 29.69
# num_of_nulls   :  4726
# num_of_uniques :  4
# 6.000    5822
# NaN      4726
# 5.000    3239
# 7.000    1908
# 8.000     224
# Name: gears, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        for group3 in list(df['gearing_type'].unique()):
            cond3 = ((df['make_model']==group1) & (df['body_type']==group2) & (df['gearing_type'] == group3))
            df.loc[cond3, 'gears'] = df.loc[cond3, 'gears'].fillna(method='ffill').fillna(method='bfill')
        
for group2 in list(df['body_type'].unique()):
    for group3 in list(df['gearing_type'].unique()):
        cond2 = ((df['body_type']==group2) & (df['gearing_type'] == group3)) 
        df.loc[cond2, "gears"] = df.loc[cond2, "gears"].fillna(method="ffill").fillna(method="bfill")
        
for group2 in list(df["body_type"].unique()):
    cond1 = df["body_type"]==group2 
    df.loc[cond1, "gears"] = df.loc[cond1, "gears"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('gears')
# Out:
# column name    :  gears
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# 6.000    8367
# 5.000    4413
# 7.000    2848
# 8.000     291
# Name: gears, dtype: int64

# %% [markdown]
# # age

# %%
df_copy = df.copy()

# %%
first_looking('age')
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 10.03
# num_of_nulls   :  1597
# num_of_uniques :  4
# 1.000    4522
# 3.000    3674
# 2.000    3273
# 0.000    2853
# NaN      1597
# Name: age, dtype: int64

# %%
df.age[df.age.isnull()] = '-'

# %%
df.boxplot(by ='age', column =['km'], grid = False)
# Out:
# <AxesSubplot:title={'center':'km'}, xlabel='age'>

# %%
df.groupby(['age']).km.describe()
# Out:
#        count      mean       std    min       25%       50%       75%  \
# age
# 0.0 2706.000  2085.355  5365.881  1.000    10.000    50.000  3000.000
# 1.0 4484.000 18035.239 11052.524  1.000  9990.000 17872.000 25078.500
# 2.0 3272.000 41754.941 28295.748  1.000 21541.750 34752.000 54805.500
# 3.0 3674.000 77442.521 39170.143 10.000 48000.000 72914.500 99950.000
# -    759.000   934.497  7416.244  0.000     5.000    10.000    10.000
#
#            max
# age
# 0.0 127022.000
# 1.0 136000.000
# 2.0 317000.000
# 3.0 291800.000
# -    89982.000

# %%
df.age[df.age == '-'] = np.nan

# %%
df['age'] = df['age'].astype('float')

# %%
df["age"][(df["age"].isnull()) & (df["km"] <= (df.km[(df.age == 0)].mean() + df.km[(df.age == 1)].mean())/2)] = 0

# %%
df["age"][(df["age"].isnull()) & (df["km"] <= (df.km[(df.age == 1)].mean() + df.km[(df.age ==2)].mean())/2)] = 1

# %%
df["age"][(df["age"].isnull()) & (df["km"] <= (df.km[(df.age ==2)].mean() + df.km[(df.age == 3)].mean())/2)] = 2

# %%
df["age"][(df["age"].isnull())] = 3

# %%
first_looking('age')
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# 1.000    4528
# 3.000    4517
# 0.000    3597
# 2.000    3277
# Name: age, dtype: int64

# %% [markdown]
# # km

# %%
first_looking('km')
# Out:
# column name    :  km
# --------------------------------
# per_of_nulls   :  % 6.43
# num_of_nulls   :  1024
# num_of_uniques :  6689
# 10.000       1045
# NaN          1024
# 1.000         367
# 5.000         170
# 50.000        148
#              ...
# 67469.000       1
# 43197.000       1
# 10027.000       1
# 35882.000       1
# 57.000          1
# Name: km, Length: 6690, dtype: int64

# %%
df.groupby(['age']).km.describe()
# Out:
#          count      mean       std    min       25%       50%       75%  \
# age
# 0.000 3450.000  1647.363  4828.824  0.000    10.000    14.000  1432.750
# 1.000 4490.000 18035.130 11046.628  1.000  9992.000 17882.500 25073.000
# 2.000 3276.000 41748.577 28279.313  1.000 21572.500 34752.000 54755.000
# 3.000 3679.000 77450.063 39145.119 10.000 48000.000 72945.000 99950.000
#
#              max
# age
# 0.000 127022.000
# 1.000 136000.000
# 2.000 317000.000
# 3.000 291800.000

# %%
df["km"][(df["km"].isnull()) & (df["age"] == 0)]  = (df.km[(df.age == 0)].mean() + df.km[(df.age == 1)].mean())/2

# %%
df["km"][(df["km"].isnull()) & (df["age"] == 1)]  = (df.km[(df.age == 1)].mean() + df.km[(df.age == 2)].mean())/2

# %%
df["km"][(df["km"].isnull()) & (df["age"] == 2)]  = (df.km[(df.age == 2)].mean() + df.km[(df.age == 3)].mean())/2

# %%
df["km"][df["km"].isnull()] = df.km[(df.age == 3)].mean()

# %%
first_looking('km')
# Out:
# column name    :  km
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6693
# 10.000       1045
# 77450.063     838
# 1.000         367
# 5.000         170
# 50.000        148
#              ...
# 67469.000       1
# 43197.000       1
# 10027.000       1
# 35882.000       1
# 57.000          1
# Name: km, Length: 6693, dtype: int64

# %% [markdown]
# # previous_owners_2

# %%
first_looking('previous_owners_2')
# Out:
# column name    :  previous_owners_2
# --------------------------------
# per_of_nulls   :  % 41.71
# num_of_nulls   :  6640
# num_of_uniques :  5
# 1.000    8294
# NaN      6640
# 2.000     778
# 0.000     188
# 3.000      17
# 4.000       2
# Name: previous_owners_2, dtype: int64

# %%
for group in list(df["age"].unique()):
    cond = df["age"] == group
    df.loc[cond, "previous_owners_2"] = df.loc[cond, "previous_owners_2"].fillna(method="ffill").fillna(method="bfill")
df["previous_owners_2"] = df["previous_owners_2"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('previous_owners_2')
# Out:
# column name    :  previous_owners_2
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  5
# 1.000    13713
# 2.000     1170
# 0.000     1005
# 3.000       29
# 4.000        2
# Name: previous_owners_2, dtype: int64

# %% [markdown]
# # hp_kw

# %%
first_looking('hp_kw')
# Out:
# column name    :  hp_kw
# --------------------------------
# per_of_nulls   :  % 0.55
# num_of_nulls   :  88
# num_of_uniques :  80
# 85.000     2542
# 66.000     2122
# 81.000     1402
# 100.000    1308
# 110.000    1112
# 70.000      888
# 125.000     707
# 51.000      695
# 55.000      569
# 118.000     516
# 92.000      466
# 121.000     392
# 147.000     380
# 77.000      345
# 56.000      286
# 54.000      276
# 103.000     253
# 87.000      232
# 165.000     194
# 88.000      177
# 60.000      160
# 162.000      98
# NaN          88
# 74.000       81
# 96.000       72
# 71.000       59
# 101.000      47
# 67.000       40
# 154.000      39
# 122.000      35
# 119.000      30
# 164.000      27
# 135.000      24
# 82.000       22
# 52.000       22
# 78.000       20
# 1.000        20
# 294.000      18
# 146.000      18
# 141.000      16
# 57.000       10
# 104.000       8
# 120.000       8
# 191.000       7
# 112.000       7
# 155.000       6
# 117.000       6
# 184.000       5
# ...

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['displacement'].unique()):
        cond2 = ((df['make_model']==group1) & (df['displacement']==group2))
        df.loc[cond2, 'hp_kw'] = df.loc[cond2, 'hp_kw'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["displacement"].unique()):
    cond1 = df["displacement"]==group1 
    df.loc[cond1, "hp_kw"] = df.loc[cond1, "hp_kw"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('hp_kw')
# Out:
# column name    :  hp_kw
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  80
# 85.000     2544
# 66.000     2130
# 81.000     1402
# 100.000    1309
# 110.000    1114
# 70.000      888
# 125.000     709
# 51.000      695
# 55.000      580
# 118.000     538
# 92.000      466
# 121.000     393
# 147.000     382
# 77.000      353
# 56.000      288
# 54.000      277
# 103.000     253
# 87.000      238
# 165.000     201
# 88.000      182
# 60.000      161
# 162.000      99
# 74.000       81
# 96.000       72
# 71.000       59
# 101.000      49
# 67.000       40
# 154.000      39
# 122.000      35
# 119.000      32
# 164.000      27
# 135.000      24
# 52.000       22
# 82.000       22
# 1.000        20
# 78.000       20
# 146.000      18
# 294.000      18
# 141.000      16
# 57.000       10
# 120.000       8
# 104.000       8
# 117.000       7
# 112.000       7
# 191.000       7
# 155.000       6
# 184.000       5
# 65.000        4
# ...

# %% [markdown]
# # type_1

# %%
first_looking('type_1')
# Out:
# column name    :  type_1
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  2
# num_of_uniques :  5
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: type_1, dtype: int64

# %%
df.type_1[df.type_1.isnull()] = 'Used'

# %%
first_looking('type_1')
# Out:
# column name    :  type_1
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  5
# Used              11098
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: type_1, dtype: int64

# %% [markdown]
# # fuel_type

# %%
first_looking('fuel_type')
# Out:
# column name    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  2
# num_of_uniques :  4
# Benzine     8551
# Diesel      7297
# LPG/CNG       64
# Electric       5
# NaN            2
# Name: fuel_type, dtype: int64

# %%
#Nan degerler Euro 6 emission_class cikti. Euro 6, Diesel oldugu icin Diesel'le doldurduk.
df.fuel_type[df.fuel_type.isnull()] = 'Diesel'

# %%
first_looking('fuel_type')
# Out:
# column name    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# Benzine     8551
# Diesel      7299
# LPG/CNG       64
# Electric       5
# Name: fuel_type, dtype: int64

# %% [markdown]
# # warranty_2

# %%
first_looking('warranty_2')
# Out:
# column name    :  warranty_2
# --------------------------------
# per_of_nulls   :  % 69.51
# num_of_nulls   :  11066
# num_of_uniques :  41
# NaN       11066
# 12.000     2594
# 24.000     1118
# 60.000      401
# 36.000      279
# 48.000      149
# 6.000       125
# 72.000       59
# 3.000        33
# 23.000       11
# 18.000       10
# 20.000        7
# 25.000        6
# 2.000         5
# 50.000        4
# 26.000        4
# 16.000        4
# 4.000         3
# 1.000         3
# 19.000        3
# 34.000        3
# 13.000        3
# 28.000        2
# 22.000        2
# 14.000        2
# 11.000        2
# 46.000        2
# 21.000        2
# 9.000         2
# 17.000        2
# 45.000        2
# 33.000        1
# 40.000        1
# 65.000        1
# 10.000        1
# 15.000        1
# 7.000         1
# 8.000         1
# 56.000        1
# 49.000        1
# 47.000        1
# 30.000        1
# Name: warranty_2, dtype: int64

# %%
# 0 model aracin garanti suresinin 60 ay oldugu bilgisiyle null degerleri yasa ve bu bilgiye gore doldurduk.
df['warranty_2'][(df['warranty_2'].isnull()) & (df['age'] == 0)] = 60

# %%
df['warranty_2'][(df['warranty_2'].isnull()) & (df['age'] == 1)] = 48

# %%
df['warranty_2'][(df['warranty_2'].isnull()) & (df['age'] == 2)] = 36

# %%
df['warranty_2'][(df['warranty_2'].isnull()) & (df['age'] == 3)] = 24

# %%
first_looking('warranty_2')
# Out:
# column name    :  warranty_2
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  41
# 24.000    4281
# 48.000    3308
# 60.000    2986
# 12.000    2594
# 36.000    2438
# 6.000      125
# 72.000      59
# 3.000       33
# 23.000      11
# 18.000      10
# 20.000       7
# 25.000       6
# 2.000        5
# 26.000       4
# 50.000       4
# 16.000       4
# 4.000        3
# 1.000        3
# 19.000       3
# 34.000       3
# 13.000       3
# 28.000       2
# 22.000       2
# 14.000       2
# 11.000       2
# 46.000       2
# 21.000       2
# 9.000        2
# 17.000       2
# 45.000       2
# 33.000       1
# 40.000       1
# 65.000       1
# 10.000       1
# 15.000       1
# 7.000        1
# 8.000        1
# 56.000       1
# 49.000       1
# 47.000       1
# 30.000       1
# Name: warranty_2, dtype: int64

# %% [markdown]
# # upholstery_type

# %%
first_looking('upholstery_type')
# Out:
# column name    :  upholstery_type
# --------------------------------
# per_of_nulls   :  % 30.6
# num_of_nulls   :  4871
# num_of_uniques :  5
# Cloth           8423
# NaN             4871
# Part leather    1499
# Full leather    1009
# Velour            60
# alcantara         57
# Name: upholstery_type, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'upholstery_type'] = df.loc[cond2, 'upholstery_type'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "upholstery_type"] = df.loc[cond1, "upholstery_type"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('upholstery_type')
# Out:
# column name    :  upholstery_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  5
# Cloth           12182
# Part leather     2109
# Full leather     1451
# alcantara          98
# Velour             79
# Name: upholstery_type, dtype: int64

# %% [markdown]
# # upholstery_color

# %%
first_looking('upholstery_color')
# Out:
# column name    :  upholstery_color
# --------------------------------
# per_of_nulls   :  % 31.9
# num_of_nulls   :  5078
# num_of_uniques :  10
# Black     8201
# NaN       5078
# Grey      1376
# Other      960
# Brown      207
# Beige       54
# Blue        16
# White       13
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery_color, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        for group3 in list(df['upholstery_type'].unique()):
            cond3 = ((df['make_model']==group1) & (df['body_type']==group2) & (df['upholstery_type'] == group3))
            df.loc[cond3, 'upholstery_color'] = df.loc[cond3, 'upholstery_color'].fillna(method='ffill').fillna(method='bfill')
        
for group2 in list(df['make_model'].unique()):
    for group3 in list(df['upholstery_type'].unique()):
        cond2 = ((df['make_model']==group2) & (df['upholstery_type'] == group3)) 
        df.loc[cond2, "upholstery_color"] = df.loc[cond2, "upholstery_color"].fillna(method="ffill").fillna(method="bfill")
        
for group2 in list(df["upholstery_type"].unique()):
    cond1 = df["body_type"]==group2 
    df.loc[cond1, "upholstery_color"] = df.loc[cond1, "upholstery_color"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('upholstery_color')
# Out:
# column name    :  upholstery_color
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  10
# Black     11853
# Grey       2039
# Other      1432
# Brown       440
# Beige        76
# White        32
# Blue         26
# Red          15
# Yellow        5
# Orange        1
# Name: upholstery_color, dtype: int64

# %% [markdown]
# # weight_kg

# %%
first_looking('weight_kg')
# Out:
# column name    :  weight_kg
# --------------------------------
# per_of_nulls   :  % 43.81
# num_of_nulls   :  6974
# num_of_uniques :  434
# NaN         6974
# 1163.000     574
# 1360.000     356
# 1165.000     301
# 1335.000     242
#             ...
# 1960.000       1
# 1258.000       1
# 1167.000       1
# 1331.000       1
# 2037.000       1
# Name: weight_kg, Length: 435, dtype: int64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        cond2 = ((df['make_model']==group1) & (df['body_type']==group2))
        df.loc[cond2, 'weight_kg'] = df.loc[cond2, 'weight_kg'].fillna(method='ffill').fillna(method='bfill')
        
for group1 in list(df["make_model"].unique()):
    cond1 = df["make_model"]==group1 
    df.loc[cond1, "weight_kg"] = df.loc[cond1, "weight_kg"].fillna(method="ffill").fillna(method="bfill")
    
# Yukaridaki kodlar Off-road bazi araclarin null degerlerini doldurmadi. Bu nedenle asagidaki kodu ekledik.    
for group3 in list(df["body_type"].unique()):
    cond3 = df["body_type"]==group3 
    df.loc[cond3, "weight_kg"] = df.loc[cond3, "weight_kg"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('weight_kg')
# Out:
# column name    :  weight_kg
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  434
# 1163.000    975
# 1165.000    582
# 1360.000    501
# 1335.000    467
# 1199.000    449
#            ...
# 1960.000      1
# 1283.000      1
# 1302.000      1
# 1294.000      1
# 2037.000      1
# Name: weight_kg, Length: 434, dtype: int64

# %% [markdown]
# # consumption_comb

# %%
first_looking('consumption_comb')
# Out:
# column name    :  consumption_comb
# --------------------------------
# per_of_nulls   :  % 12.77
# num_of_nulls   :  2033
# num_of_uniques :  72
# NaN       2033
# 5.400      770
# 3.900      733
# 4.000      713
# 5.100      657
# 4.400      623
# 5.600      618
# 4.700      602
# 3.800      585
# 4.800      546
# 5.000      545
# 4.500      523
# 5.200      454
# 4.200      435
# 4.600      426
# 4.900      393
# 5.500      380
# 5.300      380
# 3.700      369
# 5.900      369
# 4.100      342
# 5.700      342
# 6.000      331
# 4.300      307
# 3.300      307
# 3.500      288
# 6.200      216
# 3.600      194
# 6.300      181
# 6.100      175
# 5.800      164
# 6.600      148
# 6.800      136
# 3.400      106
# 6.400       75
# 3.000       69
# 7.400       66
# 6.500       43
# 6.700       43
# 7.100       38
# 10.000      34
# 6.900       27
# 3.200       25
# 8.300       20
# 7.600       14
# 7.000       10
# 3.100        7
# 7.200        6
# 7.800        6
# 8.000        5
# ...

# %%
df["consumption_comb"][(df["consumption_comb"].isnull())]  = ((df['consumption_city'] + df['consumption_country'])/2)

# %%
df["consumption_comb"][(df["consumption_comb"].isnull())]
# Out:
# 9       NaN
# 13      NaN
# 39      NaN
# 43      NaN
# 50      NaN
#          ..
# 15857   NaN
# 15883   NaN
# 15903   NaN
# 15908   NaN
# 15909   NaN
# Name: consumption_comb, Length: 1925, dtype: float64

# %%
for group1 in list(df['make_model'].unique()):
    for group2 in list(df['body_type'].unique()):
        for group3 in list(df['hp_kw'].unique()):
            cond3 = ((df['make_model']==group1) & (df['body_type']==group2) & (df['hp_kw'] == group3))
            df.loc[cond3, 'consumption_comb'] = df.loc[cond3, 'consumption_comb'].fillna(method='ffill').fillna(method='bfill')
        
for group2 in list(df['make_model'].unique()):
    for group3 in list(df['hp_kw'].unique()):
        cond2 = ((df['make_model']==group2) & (df['hp_kw'] == group3)) 
        df.loc[cond2, "consumption_comb"] = df.loc[cond2, "consumption_comb"].fillna(method="ffill").fillna(method="bfill")
        
for group3 in list(df["hp_kw"].unique()):
    cond1 = df["hp_kw"] == group3 
    df.loc[cond1, "consumption_comb"] = df.loc[cond1, "consumption_comb"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('consumption_comb')
# Out:
# column name    :  consumption_comb
# --------------------------------
# per_of_nulls   :  % 0.41
# num_of_nulls   :  65
# num_of_uniques :  78
# 5.400     854
# 3.900     804
# 4.000     782
# 5.100     737
# 5.600     730
# 4.700     709
# 4.400     686
# 3.800     672
# 5.000     627
# 4.500     603
# 4.800     585
# 4.600     536
# 5.200     519
# 4.200     474
# 3.700     453
# 5.300     447
# 4.900     446
# 5.500     427
# 4.300     416
# 5.700     412
# 5.900     392
# 4.100     387
# 3.300     366
# 6.000     352
# 3.500     314
# 6.200     233
# 3.600     215
# 6.100     191
# 6.300     188
# 5.800     182
# 6.600     156
# 6.800     146
# 3.400     137
# 6.400      84
# 3.000      76
# 7.400      71
# NaN        65
# 6.700      53
# 6.500      45
# 3.200      41
# 7.100      38
# 3.600      37
# 10.000     34
# 6.900      27
# 8.300      21
# 5.150      20
# 3.650      20
# 7.600      14
# 7.000      10
# 3.100       9
# 7.800       8
# 7.200       7
# 8.000       6
# ...

# %%
# Yukaridaki kodlar, hp_kw'nin cok cesitli olmasi nedeniyle, null degerlerin tamamini doldurmadi. Dolayisiyla kalanlari daha genel bir sutuna gore doldurduk.
for group2 in list(df["body_type"].unique()):
    cond0 = df["body_type"] == group2 
    df.loc[cond0, "consumption_comb"] = df.loc[cond0, "consumption_comb"].fillna(method="ffill").fillna(method="bfill")

# %%
first_looking('consumption_comb')
# Out:
# column name    :  consumption_comb
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  78
# 5.400     859
# 3.900     807
# 4.000     782
# 5.100     742
# 5.600     735
# 4.700     711
# 4.400     687
# 3.800     673
# 5.000     633
# 4.500     607
# 4.800     585
# 4.600     537
# 5.200     520
# 4.200     474
# 3.700     456
# 4.900     451
# 5.300     449
# 5.500     428
# 4.300     417
# 5.700     414
# 5.900     393
# 4.100     388
# 3.300     367
# 6.000     358
# 3.500     315
# 6.200     233
# 3.600     216
# 6.100     191
# 6.300     188
# 5.800     183
# 6.600     156
# 6.800     147
# 3.400     137
# 6.400      84
# 3.000      76
# 7.400      73
# 6.700      53
# 6.500      46
# 3.200      42
# 7.100      38
# 3.600      37
# 10.000     34
# 6.900      27
# 8.300      21
# 5.150      20
# 3.650      20
# 7.600      14
# 7.000      10
# 3.100       9
# 7.800       8
# 7.200       7
# 8.000       6
# 51.000      6
# ...

# %% [markdown]
# # consumption_city AND consumption_country

# %%
# Yukaridaki consumption_comb degeri yeterli goruldu ve diger tuketim sutunlari dusuruldu.
df.drop(['consumption_city', 'consumption_country'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# body_color             0
# paint_type             0
# nr._of_doors           0
# nr._of_seats           0
# gearing_type           0
# displacement           0
# cylinders              0
# drive_chain            0
# emission_class         0
# comfort&convenience    0
# entertainment&media    0
# extras                 0
# safety&security        0
# gears                  0
# age                    0
# previous_owners_2      0
# hp_kw                  0
# type_1                 0
# fuel_type              0
# particulate_filter     0
# warranty_2             0
# upholstery_type        0
# upholstery_color       0
# weight_kg              0
# consumption_comb       0
# dtype: int64

# %%
df.shape
# Out:
# (15919, 30)

# %%
df.drop('particulate_filter', axis=1, inplace=True)

# %%
df.groupby(['make_model', 'warranty_2']).price.describe()
# Out:
#                             count      mean      std       min       25%  \
# make_model     warranty_2
# Audi A1        3.000        4.000 16987.500 4884.331 12990.000 13357.500
#                6.000       21.000 18834.190 3555.108 12980.000 15990.000
#                12.000     302.000 16817.666 3727.301  9950.000 14199.250
#                13.000       1.000 19840.000      NaN 19840.000 19840.000
#                18.000       1.000 19995.000      NaN 19995.000 19995.000
# ...                           ...       ...      ...       ...       ...
# Renault Espace 36.000     126.000 27047.976 4128.515 14600.000 25000.000
#                40.000       1.000 22500.000      NaN 22500.000 22500.000
#                45.000       1.000 37950.000      NaN 37950.000 37950.000
#                48.000     180.000 32689.406 4792.220 19490.000 29499.750
#                60.000     216.000 39325.227 8096.368 23890.000 32900.000
#
#                                 50%       75%       max
# ...

# %%
df.corr()
# Out:
#                    price     km  nr._of_doors  nr._of_seats  displacement  \
# price              1.000 -0.311         0.164         0.259         0.225
# km                -0.311  1.000         0.027        -0.010         0.232
# nr._of_doors       0.164  0.027         1.000         0.101         0.070
# nr._of_seats       0.259 -0.010         0.101         1.000         0.162
# displacement       0.225  0.232         0.070         0.162         1.000
# cylinders          0.000  0.169         0.037         0.215         0.512
# gears              0.557 -0.024         0.123         0.109         0.298
# age               -0.364  0.765        -0.053        -0.083         0.156
# previous_owners_2 -0.194 -0.053        -0.138         0.005         0.053
# hp_kw              0.695  0.021         0.124         0.298         0.498
# warranty_2         0.268 -0.509        -0.052         0.071        -0.127
# weight_kg          0.415  0.151         0.126         0.299         0.445
# ...

# %%
df.to_csv('Handling_Nulls.csv', index=False)
